# %%
from sklearn.preprocessing import LabelEncoder

labels = [
    "entertainment",
    "food",
    "travel",
    "health and lifestyle",
    "mom and children",
    "fashion",
    "tech",
    "sports",
    "art",
    "gaming",
]

label_encoder = LabelEncoder()
label_encoder.fit(labels)
# Out:
# LabelEncoder()

# %%
from sklearn.preprocessing import TargetEncoder
from sklearn.model_selection import train_test_split
import pandas as pd
from consts import *
from sklearn.decomposition import PCA


FILENAME = get_filename(TT.ALL, EMBED_PROVIDER.OPENAI, MEAN_METHOD.CENTROID)
print(FILENAME)

df_embeds = pd.read_parquet(FILENAME)
df_train_all = pd.read_parquet("data/training-dataset.parquet")

df_train = pd.merge(
    df_embeds,
    df_train_all[["username", "category_enum", "label"]],
    how="left",
    on="username",
)
df_train = df_train.dropna(subset=["label"])
df_train = df_train.drop(columns=["username"])
df_train["category_enum"] = df_train["category_enum"].fillna("Missing")

df_train


df_train["target"] = label_encoder.transform(df_train["label"])
df_train = df_train.drop(columns=["label"])


X_train = df_train.drop(columns=["target"])
y_train = df_train[["target"]]


encoder = TargetEncoder()
cat_encoded_train = encoder.fit_transform(
    X_train["category_enum"].to_numpy().reshape(-1, 1), y_train["target"].tolist()
)
X_train["category_encoded"] = [row.tolist() for row in cat_encoded_train]
X_train = X_train[["embeds_wavg", "category_encoded"]]

X_train = pd.concat(
    [
        pd.DataFrame(X_train["category_encoded"].tolist()),
        pd.DataFrame(X_train["embeds_wavg"].tolist()),
    ],
    axis=1,
)


X_train, y_train = (
    X_train.to_numpy(),
    y_train.to_numpy(),
)
# Out:
# data/embeddings/openai-t3-large/ue_em_w_centroid.parquet

# %%
import xgboost as xgb
from sklearn.metrics import classification_report

dtrain = xgb.DMatrix(X_train, label=y_train)


# OpeanAI 73
params = {
    "objective": "multi:softmax",
    "num_class": 10,
    "learning_rate": 0.1,
    "max_depth": 4,
    "min_child_weight": 1,
    "subsample": 0.8,
    "colsample_bytree": 0.8,
    "reg_lambda": 1,
    "reg_alpha": 0,
    "device": "cuda",
    "random_state": 42,
    "eval_metric": ["mlogloss", "merror"],
}

evals_result = {}

model = xgb.train(
    params,
    dtrain,
    num_boost_round=150,
    evals=[(dtrain, "train")],
    evals_result=evals_result,
    verbose_eval=True,
)
# Out:
# [0]	train-mlogloss:2.06536	train-merror:0.27883
# [1]	train-mlogloss:1.88604	train-merror:0.22336
# [2]	train-mlogloss:1.74147	train-merror:0.19307
# [3]	train-mlogloss:1.62067	train-merror:0.17810
# [4]	train-mlogloss:1.51178	train-merror:0.17117
# [5]	train-mlogloss:1.41825	train-merror:0.15876
# [6]	train-mlogloss:1.33341	train-merror:0.15255
# [7]	train-mlogloss:1.25504	train-merror:0.14307
# [8]	train-mlogloss:1.18629	train-merror:0.13686
# [9]	train-mlogloss:1.12302	train-merror:0.13139
# [10]	train-mlogloss:1.06377	train-merror:0.12372
# [11]	train-mlogloss:1.00925	train-merror:0.12007
# [12]	train-mlogloss:0.95887	train-merror:0.11350
# [13]	train-mlogloss:0.91269	train-merror:0.10766
# [14]	train-mlogloss:0.86935	train-merror:0.09964
# [15]	train-mlogloss:0.82911	train-merror:0.09927
# [16]	train-mlogloss:0.79020	train-merror:0.09489
# [17]	train-mlogloss:0.75509	train-merror:0.09161
# [18]	train-mlogloss:0.72275	train-merror:0.08650
# [19]	train-mlogloss:0.69059	train-merror:0.08212
# [20]	train-mlogloss:0.66114	train-merror:0.07956
# [21]	train-mlogloss:0.63365	train-merror:0.07591
# [22]	train-mlogloss:0.60712	train-merror:0.07226
# [23]	train-mlogloss:0.58311	train-merror:0.06606
# [24]	train-mlogloss:0.55956	train-merror:0.06387
# [25]	train-mlogloss:0.53695	train-merror:0.06058
# [26]	train-mlogloss:0.51586	train-merror:0.05730
# [27]	train-mlogloss:0.49612	train-merror:0.05584
# [28]	train-mlogloss:0.47747	train-merror:0.05109
# [29]	train-mlogloss:0.45963	train-merror:0.04964
# [30]	train-mlogloss:0.44241	train-merror:0.04891
# [31]	train-mlogloss:0.42641	train-merror:0.04380
# [32]	train-mlogloss:0.41094	train-merror:0.04197
# [33]	train-mlogloss:0.39600	train-merror:0.03832
# [34]	train-mlogloss:0.38176	train-merror:0.03759
# [35]	train-mlogloss:0.36796	train-merror:0.03650
# [36]	train-mlogloss:0.35522	train-merror:0.03504
# [37]	train-mlogloss:0.34252	train-merror:0.03248
# [38]	train-mlogloss:0.33043	train-merror:0.02883
# [39]	train-mlogloss:0.31923	train-merror:0.02737
# [40]	train-mlogloss:0.30823	train-merror:0.02664
# [41]	train-mlogloss:0.29749	train-merror:0.02409
# [42]	train-mlogloss:0.28780	train-merror:0.02226
# [43]	train-mlogloss:0.27834	train-merror:0.02153
# [44]	train-mlogloss:0.26897	train-merror:0.02153
# [45]	train-mlogloss:0.26005	train-merror:0.01934
# [46]	train-mlogloss:0.25243	train-merror:0.01825
# [47]	train-mlogloss:0.24453	train-merror:0.01642
# [48]	train-mlogloss:0.23674	train-merror:0.01533
# [49]	train-mlogloss:0.22872	train-merror:0.01387
# [50]	train-mlogloss:0.22144	train-merror:0.01387
# [51]	train-mlogloss:0.21444	train-merror:0.01314
# [52]	train-mlogloss:0.20756	train-merror:0.01204
# [53]	train-mlogloss:0.20120	train-merror:0.01131
# [54]	train-mlogloss:0.19484	train-merror:0.01095
# [55]	train-mlogloss:0.18839	train-merror:0.01022
# [56]	train-mlogloss:0.18278	train-merror:0.00803
# [57]	train-mlogloss:0.17728	train-merror:0.00766
# [58]	train-mlogloss:0.17163	train-merror:0.00693
# [59]	train-mlogloss:0.16669	train-merror:0.00693
# [60]	train-mlogloss:0.16160	train-merror:0.00620
# [61]	train-mlogloss:0.15671	train-merror:0.00547
# [62]	train-mlogloss:0.15170	train-merror:0.00474
# [63]	train-mlogloss:0.14715	train-merror:0.00474
# [64]	train-mlogloss:0.14292	train-merror:0.00474
# [65]	train-mlogloss:0.13846	train-merror:0.00401
# [66]	train-mlogloss:0.13393	train-merror:0.00401
# [67]	train-mlogloss:0.13017	train-merror:0.00401
# [68]	train-mlogloss:0.12657	train-merror:0.00292
# [69]	train-mlogloss:0.12300	train-merror:0.00292
# [70]	train-mlogloss:0.11937	train-merror:0.00292
# [71]	train-mlogloss:0.11575	train-merror:0.00255
# [72]	train-mlogloss:0.11244	train-merror:0.00219
# [73]	train-mlogloss:0.10955	train-merror:0.00255
# [74]	train-mlogloss:0.10641	train-merror:0.00219
# [75]	train-mlogloss:0.10351	train-merror:0.00219
# [76]	train-mlogloss:0.10082	train-merror:0.00146
# [77]	train-mlogloss:0.09799	train-merror:0.00146
# [78]	train-mlogloss:0.09529	train-merror:0.00146
# [79]	train-mlogloss:0.09277	train-merror:0.00146
# [80]	train-mlogloss:0.09023	train-merror:0.00146
# [81]	train-mlogloss:0.08769	train-merror:0.00109
# [82]	train-mlogloss:0.08543	train-merror:0.00109
# [83]	train-mlogloss:0.08332	train-merror:0.00109
# [84]	train-mlogloss:0.08105	train-merror:0.00109
# [85]	train-mlogloss:0.07881	train-merror:0.00109
# [86]	train-mlogloss:0.07683	train-merror:0.00109
# [87]	train-mlogloss:0.07473	train-merror:0.00036
# [88]	train-mlogloss:0.07297	train-merror:0.00036
# [89]	train-mlogloss:0.07133	train-merror:0.00073
# [90]	train-mlogloss:0.06955	train-merror:0.00036
# [91]	train-mlogloss:0.06758	train-merror:0.00036
# [92]	train-mlogloss:0.06597	train-merror:0.00036
# [93]	train-mlogloss:0.06441	train-merror:0.00036
# [94]	train-mlogloss:0.06284	train-merror:0.00036
# [95]	train-mlogloss:0.06136	train-merror:0.00036
# [96]	train-mlogloss:0.05973	train-merror:0.00036
# [97]	train-mlogloss:0.05833	train-merror:0.00036
# [98]	train-mlogloss:0.05687	train-merror:0.00036
# [99]	train-mlogloss:0.05568	train-merror:0.00036
# [100]	train-mlogloss:0.05439	train-merror:0.00036
# [101]	train-mlogloss:0.05315	train-merror:0.00036
# [102]	train-mlogloss:0.05193	train-merror:0.00036
# [103]	train-mlogloss:0.05072	train-merror:0.00036
# [104]	train-mlogloss:0.04960	train-merror:0.00036
# [105]	train-mlogloss:0.04853	train-merror:0.00036
# [106]	train-mlogloss:0.04758	train-merror:0.00036
# [107]	train-mlogloss:0.04653	train-merror:0.00036
# [108]	train-mlogloss:0.04557	train-merror:0.00036
# [109]	train-mlogloss:0.04464	train-merror:0.00036
# [110]	train-mlogloss:0.04368	train-merror:0.00036
# [111]	train-mlogloss:0.04276	train-merror:0.00036
# [112]	train-mlogloss:0.04191	train-merror:0.00036
# [113]	train-mlogloss:0.04112	train-merror:0.00036
# [114]	train-mlogloss:0.04031	train-merror:0.00036
# [115]	train-mlogloss:0.03944	train-merror:0.00036
# [116]	train-mlogloss:0.03857	train-merror:0.00036
# [117]	train-mlogloss:0.03772	train-merror:0.00036
# [118]	train-mlogloss:0.03698	train-merror:0.00036
# [119]	train-mlogloss:0.03619	train-merror:0.00000
# [120]	train-mlogloss:0.03551	train-merror:0.00000
# [121]	train-mlogloss:0.03479	train-merror:0.00000
# [122]	train-mlogloss:0.03415	train-merror:0.00000
# [123]	train-mlogloss:0.03349	train-merror:0.00000
# [124]	train-mlogloss:0.03289	train-merror:0.00000
# [125]	train-mlogloss:0.03221	train-merror:0.00000
# [126]	train-mlogloss:0.03160	train-merror:0.00000
# [127]	train-mlogloss:0.03098	train-merror:0.00000
# [128]	train-mlogloss:0.03036	train-merror:0.00000
# [129]	train-mlogloss:0.02976	train-merror:0.00000
# [130]	train-mlogloss:0.02917	train-merror:0.00000
# [131]	train-mlogloss:0.02861	train-merror:0.00000
# [132]	train-mlogloss:0.02812	train-merror:0.00000
# [133]	train-mlogloss:0.02758	train-merror:0.00000
# [134]	train-mlogloss:0.02713	train-merror:0.00000
# [135]	train-mlogloss:0.02664	train-merror:0.00000
# [136]	train-mlogloss:0.02615	train-merror:0.00000
# [137]	train-mlogloss:0.02572	train-merror:0.00000
# [138]	train-mlogloss:0.02525	train-merror:0.00000
# [139]	train-mlogloss:0.02481	train-merror:0.00000
# [140]	train-mlogloss:0.02435	train-merror:0.00000
# [141]	train-mlogloss:0.02392	train-merror:0.00000
# [142]	train-mlogloss:0.02353	train-merror:0.00000
# [143]	train-mlogloss:0.02314	train-merror:0.00000
# [144]	train-mlogloss:0.02278	train-merror:0.00000
# [145]	train-mlogloss:0.02245	train-merror:0.00000
# [146]	train-mlogloss:0.02211	train-merror:0.00000
# [147]	train-mlogloss:0.02179	train-merror:0.00000
# [148]	train-mlogloss:0.02145	train-merror:0.00000
# [149]	train-mlogloss:0.02107	train-merror:0.00000

# %%
model.save_model('trained_models/xgb_openai_centroid.json')
